# %% [markdown]
# <a href="https://colab.research.google.com/github/royalalexandar404/ComputerVision_Assignment1/blob/main/ComputerVision_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://images.cocodataset.org/zips/val2017.zip
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2026-03-30 09:12:06--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 16.182.64.25, 16.15.191.220, 3.5.12.168, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|16.182.64.25|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘val2017.zip’
#
# val2017.zip         100%[===================>] 777.80M  18.6MB/s    in 48s
#
# 2026-03-30 09:12:54 (16.2 MB/s) - ‘val2017.zip’ saved [815585330/815585330]
#
# --2026-03-30 09:12:55--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 54.231.139.217, 16.15.252.52, 54.231.161.193, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|54.231.139.217|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# ...

# %%
# !unzip val2017.zip
# !unzip annotations_trainval2017.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: val2017/000000365745.jpg
#  extracting: val2017/000000320425.jpg
#  extracting: val2017/000000481404.jpg
#  extracting: val2017/000000314294.jpg
#  extracting: val2017/000000335328.jpg
#  extracting: val2017/000000513688.jpg
#  extracting: val2017/000000158548.jpg
#  extracting: val2017/000000132116.jpg
#  extracting: val2017/000000415238.jpg
#  extracting: val2017/000000321333.jpg
#  extracting: val2017/000000081738.jpg
#  extracting: val2017/000000577584.jpg
#  extracting: val2017/000000346905.jpg
#  extracting: val2017/000000433980.jpg
#  extracting: val2017/000000228144.jpg
#  extracting: val2017/000000041872.jpg
#  extracting: val2017/000000117492.jpg
#  extracting: val2017/000000368900.jpg
#  extracting: val2017/000000376900.jpg
#  extracting: val2017/000000352491.jpg
#  extracting: val2017/000000330790.jpg
#  extracting: val2017/000000384850.jpg
#  extracting: val2017/000000032735.jpg
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget -P /content/drive/MyDrive/ComputerVision_Assignment1 http://images.cocodataset.org/zips/val2017.zip
# !wget -P /content/drive/MyDrive/ComputerVision_Assignment1 http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2026-03-30 09:17:33--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 3.5.29.19, 52.217.206.49, 16.15.228.123, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|3.5.29.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘/content/drive/MyDrive/ComputerVision_Assignment1/val2017.zip’
#
# val2017.zip         100%[===================>] 777.80M  13.9MB/s    in 58s
#
# 2026-03-30 09:18:31 (13.5 MB/s) - ‘/content/drive/MyDrive/ComputerVision_Assignment1/val2017.zip’ saved [815585330/815585330]
#
# --2026-03-30 09:18:31--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 16.15.183.167, 16.15.207.10, 16.15.228.47, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|16.15.183.167|:80... connected.
# ...

# %%
# !unzip /content/drive/MyDrive/ComputerVision_Assignment1/val2017.zip -d /content/drive/MyDrive/ComputerVision_Assignment1
# !unzip /content/drive/MyDrive/ComputerVision_Assignment1/annotations_trainval2017.zip -d /content/drive/MyDrive/ComputerVision_Assignment1
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/MyDrive/ComputerVision_Assignment1/val2017/000000320425.jpg
#  extracting: /content/drive/MyDrive/ComputerVision_Assignment1/val2017/000000481404.jpg
#  extracting: /content/drive/MyDrive/ComputerVision_Assignment1/val2017/000000314294.jpg
#  extracting: /content/drive/MyDrive/ComputerVision_Assignment1/val2017/000000335328.jpg
#  extracting: /content/drive/MyDrive/ComputerVision_Assignment1/val2017/000000513688.jpg
#  extracting: /content/drive/MyDrive/ComputerVision_Assignment1/val2017/000000158548.jpg
#  extracting: /content/drive/MyDrive/ComputerVision_Assignment1/val2017/000000132116.jpg
#  extracting: /content/drive/MyDrive/ComputerVision_Assignment1/val2017/000000415238.jpg
#  extracting: /content/drive/MyDrive/ComputerVision_Assignment1/val2017/000000321333.jpg
#  extracting: /content/drive/MyDrive/ComputerVision_Assignment1/val2017/000000081738.jpg
# ...

# %%
import os
blur_path = "/content/drive/MyDrive/assignment_data/blurred"
clean_path = "/content/drive/MyDrive/assignment_data/val2017"

blur_images = set(os.listdir(blur_path))
clean_images = set(os.listdir(clean_path))

common = blur_images.intersection(clean_images)
print("Blur images: ", len(blur_images))
print("Clean images: ", len(clean_images))
print("Matching images: ", len(common))

missing_clean = blur_images - clean_images
missing_blur = clean_images - blur_images

print("Missing clean images: ", len(missing_clean))
print("Missing blur images: ", len(missing_blur))
# Out:
# Blur images:  3870
# Clean images:  5000
# Matching images:  3870
# Missing clean images:  0
# Missing blur images:  1130

# %%
import random
import matplotlib.pyplot as plt
from PIL import Image

sample = random.choice(list(common))
blur_img = Image.open(os.path.join(blur_path, sample))
clean_img = Image.open(os.path.join(clean_path, sample))
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(blur_img)
plt.title("Blurred image")

plt.subplot(1,2,2)
plt.imshow(clean_img)
plt.title("Clean image")
plt.show()

# %%
import cv2
import numpy as np

def wiener_filter(img, kernel_size=5):
  kernel = np.ones((kernel_size, kernel_size)) / (kernel_size**2)
  img_fft = np.fft.fft2(img)
  kernel_fft = np.fft.fft2(kernel, s=img.shape)
  kernel_fft_conj = np.conj(kernel_fft)
  wiener = kernel_fft_conj / (np.abs(kernel_fft)**2 + 0.01)

  result_fft = wiener * img_fft
  result = np.abs(np.fft.ifft2(result_fft))

  return result

# %%
img = cv2.imread(os.path.join(blur_path, sample), 0)
deblurred = wiener_filter(img)

plt.imshow(deblurred, cmap='gray')
plt.title("Deblurred Image")
plt.show()

# %%
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
import numpy as np

clean_gray = clean_gray.astype(np.float32)
deblurred = deblurred.astype(np.float32)
deblurred = np.clip(deblurred, 0, 255)
psnr = peak_signal_noise_ratio(clean_gray, deblurred, data_range=255)
ssim = structural_similarity(clean_gray, deblurred, data_range=255)
print("PSNR: ", psnr)
print("SSIM: ", ssim)
# Out:
# PSNR:  17.81557637568209
# SSIM:  0.21022089518363116

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
import os
import cv2
import numpy as np

sample_name = sample
blur_file = os.path.join(blur_path, sample_name)
clean_file = os.path.join(clean_path, sample_name)

deblur_save_dir = "/content/deblurred_samples"
os.makedirs(deblur_save_dir, exist_ok=True)
deblur_file = os.path.join(deblur_save_dir, sample_name)
deblur_to_save = np.clip(deblurred, 0, 255).astype(np.uint8)
cv2.imwrite(deblur_file, deblur_to_save)
# Out:
# True

# %%
results_blur = model(blur_file)
results_deblur = model(deblur_file)
results_clean = model(clean_file)
# Out:
# image 1/1 /content/drive/MyDrive/assignment_data/blurred/000000271457.jpg: 448x640 (no detections), 615.5ms
# Speed: 29.3ms preprocess, 615.5ms inference, 28.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/deblurred_samples/000000271457.jpg: 448x640 (no detections), 267.2ms
# Speed: 3.7ms preprocess, 267.2ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/assignment_data/val2017/000000271457.jpg: 448x640 1 bench, 272.7ms
# Speed: 3.4ms preprocess, 272.7ms inference, 28.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
blur_vis = results_blur[0].plot()
deblur_vis = results_deblur[0].plot()
clean_vis = results_clean[0].plot()

plt.figure(figsize=(18,6))
